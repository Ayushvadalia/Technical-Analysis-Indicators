# %%
import pandas as pd

# %%
df=pd.read_csv('/content/NIFTY IT-01-07-2022-to-01-07-2023.csv')

# %%
pip install ta
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29412 sha256=c99676b74cc22588d43bfdcc0d33ea2b07cbf07ec5d71a400b589fab2685c9a6
#   Stored in directory: /root/.cache/pip/wheels/5f/67/4f/8a9f252836e053e532c6587a3230bc72a4deb16b03a829610b
# Successfully built ta
# ...

# %%
import ta

# %% [markdown]
# #ADX Indicators
# At its most basic, the Average Directional Index (ADX) can be used to determine if a security is trending or not. This determination helps traders choose between a trend-following system or a non-trend-following system. Wilder suggests that a strong trend is present when ADX is above 25 and no trend is present when ADX is below 20. There appears to be a gray zone between 20 and 25. As noted above, chartists may need to adjust the settings to increase sensitivity and signals. ADX also has a fair amount of lag because of all the smoothing techniques. Many technical analysts use 20 as the key level for ADX.

# %%
df['ADX']=ta.trend.ADXIndicator(df['High'],df['Low'],df['Close'],window=14,fillna=False).adx()

# %%
#df['ADX_Neg']=ta.trend.ADXIndicator(df['High'],df['Low'],df['Close'],window=14,fillna=False).adx_neg()
#df['ADX_Pos']=ta.trend.ADXIndicator(df['High'],df['Low'],df['Close'],window=14,fillna=False).adx_pos()

# %%
# prompt: Plot the above column in plotly

import plotly.graph_objects as go

fig = go.Figure(data=[go.Scatter(x=df.index, y=df['ADX'])])
fig.update_layout(title='ADX Indicator',
                  xaxis_title='Date',
                  yaxis_title='ADX')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Aroon Indicator
#
# The indicator focuses on the last 25 periods but is scaled to zero and 100. Therefore, an AroonUp reading above 50 means the price made a new high within the last 12.5 periods. A reading near 100 means a high was seen very recently. The same concepts apply to the AroonDown. When it is above 50, a low was witnessed within the 12.5 periods. An AroonDown reading near 100 means a low was seen very recently.

# %%
df['Aroon_Down']=ta.trend.AroonIndicator(df['Close'],df['Low'],window=14,fillna=False).aroon_down()
df['Aroon_Up']=ta.trend.AroonIndicator(df['Close'],df['Low'],window=14,fillna=False).aroon_up()
df['Arron']=ta.trend.AroonIndicator(df['Close'],df['Low'],window=14,fillna=False).aroon_indicator()

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(x=df.index, y=df['Aroon_Down'], mode='lines', name='Down'))
fig.add_trace(go.Scatter(x=df.index, y=df['Aroon_Up'], mode='lines', name='Up'))
fig.add_trace(go.Scatter(x=df.index, y=df['Arron'], mode='lines', name='Aroon'))

fig.update_layout(title='Aroon Indicator',
                  xaxis_title='Date',
                  yaxis_title='Percentage')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
